# %%
#!/usr/bin/env python3
from os import listdir
from numpy import asarray
from numpy import save
from glob import glob
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import sys
import cv2 as cv

cat_files = glob('Cat*.jpg')
dog_files = glob('Dog*.jpg')
input_files = cat_files + dog_files

# input_files = 'input_files.txt'
# norm_img = np.zeros((800,800))
photos, labels = list(), list()
resized_images = 'resized_images.txt'
labels = 'labels.txt'

for i in range(len(input_files)):
    if 'Cat' in input_files[i]:
        output = 1.0
        photo = load_img(input_files[i], target_size=(200, 200))
        photo.save('resized_Cat'+ str(i) + '.jpg', 'JPEG', quality=90)
        photos.append(photo)
        labels.append(output)
    else:
        output = 0.0
        photo = load_img(input_files[i], target_size=(200, 200))
        photo.save('resized_Dog'+ str(i) + '.jpg', 'JPEG', quality=90)
        photos.append(photo)
        labels.append(output)  
        
# with open(resized_images, 'w') as f:
#     for item in photos:
#         f.write("%s\n" % item)

# with open(labels, 'w') as f:
#     for item in labels:
#         f.write("%s\n" % item)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-af3918bef9dc> in <module>
#      27         photo.save('resized_Cat'+ str(i) + '.jpg', 'JPEG', quality=90)
#      28         photos.append(photo)
# ---> 29         labels.append(str(output))
#      30     else:
#      31         output = 0.0
#
# AttributeError: 'str' object has no attribute 'append'

# %%
cat_files = glob('Cat*.jpg')
# cat_files = cat_files.sort()
dog_files = glob('Dog*.jpg')
# dog_files = dog_files.sort()
photos, labels = list(), list()
# enumerate files in the directory

for i in range(len(cat_files)):
    output = 1.0
    photo = load_img(cat_files[i], target_size=(200, 200))
    photo.save('resized_Cat'+ str(i) + '.jpg', 'JPEG', quality=90)
    photos.append(photo)
    labels.append(output)
    
for i in range(len(dog_files)):
    output = 0.0
    photo = load_img(dog_files[i], target_size=(200, 200))
    photo.save('resized_Dog'+ str(i) + '.jpg', 'JPEG', quality=90)
    photos.append(photo)
    labels.append(output)   

resized_images = 'resized_images.txt'
labels = 'labels.txt'

        
with open(resized_images, 'w') as f:
    for item in photos:
        f.write("%s\n" % item)

with open(labels, 'w') as f:
    for item in labels:
        f.write("%s\n" % item)

# %%
cat_files.sort()

# %%
cat_files
# Out:
# ['Cat0.jpg',
#  'Cat1.jpg',
#  'Cat10.jpg',
#  'Cat11.jpg',
#  'Cat12.jpg',
#  'Cat13.jpg',
#  'Cat14.jpg',
#  'Cat15.jpg',
#  'Cat16.jpg',
#  'Cat17.jpg',
#  'Cat18.jpg',
#  'Cat19.jpg',
#  'Cat2.jpg',
#  'Cat20.jpg',
#  'Cat21.jpg',
#  'Cat22.jpg',
#  'Cat23.jpg',
#  'Cat24.jpg',
#  'Cat25.jpg',
#  'Cat26.jpg',
#  'Cat27.jpg',
#  'Cat28.jpg',
#  'Cat29.jpg',
#  'Cat3.jpg',
#  'Cat30.jpg',
#  'Cat31.jpg',
#  'Cat32.jpg',
#  'Cat33.jpg',
#  'Cat34.jpg',
#  'Cat35.jpg',
#  'Cat36.jpg',
#  'Cat37.jpg',
#  'Cat38.jpg',
#  'Cat39.jpg',
#  'Cat4.jpg',
#  'Cat40.jpg',
#  'Cat41.jpg',
#  'Cat42.jpg',
#  'Cat43.jpg',
#  'Cat44.jpg',
#  'Cat45.jpg',
#  'Cat46.jpg',
#  'Cat47.jpg',
#  'Cat48.jpg',
#  'Cat49.jpg',
#  'Cat5.jpg',
#  'Cat50.jpg',
#  'Cat51.jpg',
#  'Cat52.jpg',
#  'Cat53.jpg',
#  'Cat54.jpg',
#  'Cat55.jpg',
#  'Cat56.jpg',
#  'Cat57.jpg',
#  'Cat58.jpg',
#  'Cat59.jpg',
#  'Cat6.jpg',
#  'Cat60.jpg',
#  'Cat61.jpg',
#  'Cat62.jpg',
#  'Cat63.jpg',
#  'Cat64.jpg',
# ...
